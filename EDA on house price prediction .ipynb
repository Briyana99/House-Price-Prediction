# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ranab\\Downloads\\Housing (1).csv")

# %%
df.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
X=df.describe()   #Statistical model of our dataset.
X.style.background_gradient(cmap = "YlGn")
# Out:
# <style type="text/css">
# #T_5bfb3_row0_col0, #T_5bfb3_row0_col1, #T_5bfb3_row1_col3, #T_5bfb3_row1_col4, #T_5bfb3_row1_col5, #T_5bfb3_row2_col2, #T_5bfb3_row2_col3, #T_5bfb3_row2_col4, #T_5bfb3_row2_col5, #T_5bfb3_row3_col2, #T_5bfb3_row3_col3, #T_5bfb3_row3_col4, #T_5bfb3_row3_col5, #T_5bfb3_row4_col2, #T_5bfb3_row4_col3, #T_5bfb3_row4_col4, #T_5bfb3_row4_col5, #T_5bfb3_row5_col3, #T_5bfb3_row5_col4, #T_5bfb3_row5_col5, #T_5bfb3_row6_col3, #T_5bfb3_row6_col4, #T_5bfb3_row6_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5bfb3_row0_col2, #T_5bfb3_row0_col3, #T_5bfb3_row0_col4, #T_5bfb3_row0_col5, #T_5bfb3_row7_col0, #T_5bfb3_row7_col1 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_5bfb3_row1_col0 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_5bfb3_row1_col1 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# ...

# %%
plt.figure()                                             #heatmap displaying correlation among all attributes.
cor = df.corr()
fig = plt.gcf()
fig.set_size_inches(12,8)
sns.set(rc={'figure.figsize':(20,15)})
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
import missingno                   #the white line in the matrix drawn below is the null values.
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(df['price'], ax = axs[0,1],color='blue')
plt2 = sns.boxplot(df['area'], ax = axs[0,0],color='red')
plt3 = sns.boxplot(df['bedrooms'], ax = axs[0,2],color='green')
plt1 = sns.boxplot(df['bathrooms'], ax = axs[1,0],color='yellow')
plt2 = sns.boxplot(df['stories'], ax = axs[1,1],color='orange')
plt3 = sns.boxplot(df['parking'], ax = axs[1,2])
# Out:
# C:\Users\ranab\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ranab\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ranab\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
counts = df['furnishingstatus'].value_counts().values
plt.figure(figsize=(5,6))
l = df['furnishingstatus'].value_counts().index
colors = ['red','pink','yellow']
plt.pie(counts,autopct = '%1.1f%%',labels=l,colors = colors)
plt.show()

# %%
df['parking'].hist(figsize = (10, 6),color='orange') 
plt.xlabel('parking lot')
plt.ylabel('value')
plt.show()

# %%
df['bedrooms'].hist(figsize = (10, 6),color='blue') 
#plt.plot(df['bedrooms'],df['price'])
plt.xlabel('Number of bedrooms')
plt.ylabel('value')
plt.show()

# %%
sns.lineplot(x= df['price'],y = df['area'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='area'>

# %%
fig = plt.gcf()
fig.set_size_inches(5,6)
sns.scatterplot(df["price"],df["area"],color='red')
# Out:
# C:\Users\ranab\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='area'>

# %%
fig = plt.figure()
sns.distplot(df['price'], bins = 20)
#fig.suptitle('Error Ter', fontsize = 20)                  # Plot heading 
plt.xlabel('Price', fontsize = 18)
# Out:
# C:\Users\ranab\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Price')
